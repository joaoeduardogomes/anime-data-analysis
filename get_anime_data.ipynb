# %%
import pandas as pd
import requests
import json
import os
from dotenv import load_dotenv

# %%
load_dotenv()

CLIENT_ID = os.getenv("MAL_CLIENT_ID")

# %%
url = "https://api.myanimelist.net/v2/anime/ranking"
API_FIELDS = ["mean","popularity","media_type","source","genres","rating"]

headers = {
    "X-MAL-CLIENT-ID": CLIENT_ID
}

params = {
    "ranking_type": "all",
    "limit": 500,
    "fields": ",".join(API_FIELDS)
}

# %%
response = requests.get(url, headers=headers, params=params)

print(response.status_code)

data = response.json() #check the status code
print(len(data["data"])) #check if we have the correct number of titles
# Out:
# 200
# 500

# %%
result = []

DEMOGRAPHIC_NAMES = {"Shounen", "Seinen", "Shoujo", "Josei"}

for item in data['data']:
    node = item['node']

    genres_list = [genre["name"] for genre in node.get("genres", [])]

    genres = [genre for genre in genres_list if genre not in DEMOGRAPHIC_NAMES]
    demographic = [genre for genre in genres_list if genre in DEMOGRAPHIC_NAMES]
    #if not demographic:
        #demographic = ["Undefined"]

    result.append({
        "rank": item['ranking']['rank'],
        "score": node.get('mean'),
        "popularity": node.get('popularity'),
        "title": node['title'],
        "type": node.get('media_type'),
        "source": node.get('source'),
        "genres": ", ".join(genres),
        "demographic": ", ".join(demographic),
        "rating": node.get('rating')
    })

print(json.dumps(result[0], indent=2))
# Out:
# {
#   "rank": 1,
#   "score": 9.29,
#   "popularity": 120,
#   "title": "Sousou no Frieren",
#   "type": "tv",
#   "source": "manga",
#   "genres": "Adventure, Drama, Fantasy",
#   "demographic": "Shounen",
#   "rating": "pg_13"
# }

# %%
#turn the lst of dict into dataframe
COLUMNS = ["rank","score","popularity","title","type","source","genres","demographic","rating"]
df = pd.DataFrame(result, columns=COLUMNS)
df.head(10).style.hide(axis="index") #show data without the index
# Out:
# <style type="text/css">
# </style>
# <table id="T_623b7">
#   <thead>
#     <tr>
#       <th id="T_623b7_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_623b7_level0_col1" class="col_heading level0 col1" >score</th>
#       <th id="T_623b7_level0_col2" class="col_heading level0 col2" >popularity</th>
#       <th id="T_623b7_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_623b7_level0_col4" class="col_heading level0 col4" >type</th>
#       <th id="T_623b7_level0_col5" class="col_heading level0 col5" >source</th>
#       <th id="T_623b7_level0_col6" class="col_heading level0 col6" >genres</th>
#       <th id="T_623b7_level0_col7" class="col_heading level0 col7" >demographic</th>
#       <th id="T_623b7_level0_col8" class="col_heading level0 col8" >rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_623b7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_623b7_row0_col1" class="data row0 col1" >9.290000</td>
#       <td id="T_623b7_row0_col2" class="data row0 col2" >120</td>
#       <td id="T_623b7_row0_col3" class="data row0 col3" >Sousou no Frieren</td>
#       <td id="T_623b7_row0_col4" class="data row0 col4" >tv</td>
#       <td id="T_623b7_row0_col5" class="data row0 col5" >manga</td>
#       <td id="T_623b7_row0_col6" class="data row0 col6" >Adventure, Drama, Fantasy</td>
#       <td id="T_623b7_row0_col7" class="data row0 col7" >Shounen</td>
#       <td id="T_623b7_row0_col8" class="data row0 col8" >pg_13</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_623b7_row1_col1" class="data row1 col1" >9.140000</td>
#       <td id="T_623b7_row1_col2" class="data row1 col2" >830</td>
#       <td id="T_623b7_row1_col3" class="data row1 col3" >Chainsaw Man Movie: Reze-hen</td>
#       <td id="T_623b7_row1_col4" class="data row1 col4" >movie</td>
#       <td id="T_623b7_row1_col5" class="data row1 col5" >manga</td>
#       <td id="T_623b7_row1_col6" class="data row1 col6" >Action, Fantasy, Gore, Urban Fantasy</td>
#       <td id="T_623b7_row1_col7" class="data row1 col7" >Shounen</td>
#       <td id="T_623b7_row1_col8" class="data row1 col8" >r</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_623b7_row2_col1" class="data row2 col1" >9.100000</td>
#       <td id="T_623b7_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_623b7_row2_col3" class="data row2 col3" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_623b7_row2_col4" class="data row2 col4" >tv</td>
#       <td id="T_623b7_row2_col5" class="data row2 col5" >manga</td>
#       <td id="T_623b7_row2_col6" class="data row2 col6" >Action, Adventure, Drama, Fantasy, Military</td>
#       <td id="T_623b7_row2_col7" class="data row2 col7" >Shounen</td>
#       <td id="T_623b7_row2_col8" class="data row2 col8" >r</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_623b7_row3_col1" class="data row3 col1" >9.070000</td>
#       <td id="T_623b7_row3_col2" class="data row3 col2" >14</td>
#       <td id="T_623b7_row3_col3" class="data row3 col3" >Steins;Gate</td>
#       <td id="T_623b7_row3_col4" class="data row3 col4" >tv</td>
#       <td id="T_623b7_row3_col5" class="data row3 col5" >visual_novel</td>
#       <td id="T_623b7_row3_col6" class="data row3 col6" >Drama, Psychological, Sci-Fi, Suspense, Time Travel</td>
#       <td id="T_623b7_row3_col7" class="data row3 col7" ></td>
#       <td id="T_623b7_row3_col8" class="data row3 col8" >pg_13</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_623b7_row4_col1" class="data row4 col1" >9.050000</td>
#       <td id="T_623b7_row4_col2" class="data row4 col2" >21</td>
#       <td id="T_623b7_row4_col3" class="data row4 col3" >Shingeki no Kyojin Season 3 Part 2</td>
#       <td id="T_623b7_row4_col4" class="data row4 col4" >tv</td>
#       <td id="T_623b7_row4_col5" class="data row4 col5" >manga</td>
#       <td id="T_623b7_row4_col6" class="data row4 col6" >Action, Drama, Gore, Military, Survival, Suspense</td>
#       <td id="T_623b7_row4_col7" class="data row4 col7" >Shounen</td>
#       <td id="T_623b7_row4_col8" class="data row4 col8" >r</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_623b7_row5_col1" class="data row5 col1" >9.050000</td>
#       <td id="T_623b7_row5_col2" class="data row5 col2" >1512</td>
#       <td id="T_623b7_row5_col3" class="data row5 col3" >Gintama: The Final</td>
#       <td id="T_623b7_row5_col4" class="data row5 col4" >movie</td>
#       <td id="T_623b7_row5_col5" class="data row5 col5" >manga</td>
#       <td id="T_623b7_row5_col6" class="data row5 col6" >Action, Comedy, Drama, Gag Humor, Historical, Parody, Samurai, Sci-Fi</td>
#       <td id="T_623b7_row5_col7" class="data row5 col7" >Shounen</td>
#       <td id="T_623b7_row5_col8" class="data row5 col8" >pg_13</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_623b7_row6_col1" class="data row6 col1" >9.050000</td>
#       <td id="T_623b7_row6_col2" class="data row6 col2" >347</td>
#       <td id="T_623b7_row6_col3" class="data row6 col3" >Gintama°</td>
#       <td id="T_623b7_row6_col4" class="data row6 col4" >tv</td>
#       <td id="T_623b7_row6_col5" class="data row6 col5" >manga</td>
#       <td id="T_623b7_row6_col6" class="data row6 col6" >Action, Comedy, Gag Humor, Historical, Parody, Samurai, Sci-Fi</td>
#       <td id="T_623b7_row6_col7" class="data row6 col7" >Shounen</td>
#       <td id="T_623b7_row6_col8" class="data row6 col8" >pg_13</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_623b7_row7_col1" class="data row7 col1" >9.040000</td>
#       <td id="T_623b7_row7_col2" class="data row7 col2" >4670</td>
#       <td id="T_623b7_row7_col3" class="data row7 col3" >Kingdom 6th Season</td>
#       <td id="T_623b7_row7_col4" class="data row7 col4" >tv</td>
#       <td id="T_623b7_row7_col5" class="data row7 col5" >manga</td>
#       <td id="T_623b7_row7_col6" class="data row7 col6" >Action, Historical, Military</td>
#       <td id="T_623b7_row7_col7" class="data row7 col7" >Seinen</td>
#       <td id="T_623b7_row7_col8" class="data row7 col8" >r</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_623b7_row8_col1" class="data row8 col1" >9.030000</td>
#       <td id="T_623b7_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_623b7_row8_col3" class="data row8 col3" >Hunter x Hunter (2011)</td>
#       <td id="T_623b7_row8_col4" class="data row8 col4" >tv</td>
#       <td id="T_623b7_row8_col5" class="data row8 col5" >manga</td>
#       <td id="T_623b7_row8_col6" class="data row8 col6" >Action, Adventure, Fantasy</td>
#       <td id="T_623b7_row8_col7" class="data row8 col7" >Shounen</td>
#       <td id="T_623b7_row8_col8" class="data row8 col8" >pg_13</td>
#     </tr>
#     <tr>
#       <td id="T_623b7_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_623b7_row9_col1" class="data row9 col1" >9.020000</td>
#       <td id="T_623b7_row9_col2" class="data row9 col2" >753</td>
#       <td id="T_623b7_row9_col3" class="data row9 col3" >Ginga Eiyuu Densetsu</td>
#       <td id="T_623b7_row9_col4" class="data row9 col4" >ova</td>
#       <td id="T_623b7_row9_col5" class="data row9 col5" >novel</td>
#       <td id="T_623b7_row9_col6" class="data row9 col6" >Adult Cast, Drama, Military, Sci-Fi, Space</td>
#       <td id="T_623b7_row9_col7" class="data row9 col7" ></td>
#       <td id="T_623b7_row9_col8" class="data row9 col8" >r</td>
#     </tr>
#   </tbody>
# </table>

# %%
#save to csv file
df.to_csv("anime_data.csv", index=False)
